# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# %%
sheet1 = pd.read_excel('data/CLEAN_STUDY14.xlsx')
sheet1 = sheet1.rename(columns = {"SUBJECTID" : "SID"})
sheet1['STUDY'] = '14'
sheet1
# Out:
#            SID CATEGORY  DELAY     IP  IP VALUE  \
# 0    UB2MD201P      EFT     30   IP30    789.06
# 1    UB2MD201P      EFT    180  IP180    554.70
# 2    UB2MD201P      EFT    365  IP365    632.80
# 3     UB2MD207      EFT     30   IP30    351.56
# 4     UB2MD207      EFT    180  IP180    117.20
# ..         ...      ...    ...    ...       ...
# 223   VT2MD279      ERT      6    IP6      0.00
# 224   VT2MD279      ERT     12   IP12      0.00
# 225   VT2MD290      ERT      1    IP1      0.00
# 226   VT2MD290      ERT      6    IP6      0.00
# 227   VT2MD290      ERT     12   IP12      0.00
#
#                                                   CUES STUDY
# 0    in about 1 month i am at the movies with my co...    14
# 1    in about 6 months my sister carolyn is home fr...    14
# 2    In about 1 year i am planning for christmas.  ...    14
# 3    In about one month I am kayaking on Lake Erie....    14
# 4    In about 6 months I am at the WHO concert in C...    14
# ...

# %%
sheet2 = pd.read_excel('data/CLEAN_STUDY15.xlsx')
sheet2 = sheet2.rename(columns = {"ID":"SID", "IP100 VALUE": "IP VALUE"})
sheet2['STUDY'] = '15'
sheet2
# Out:
#      SID CATEGORY  DELAY      IP  IP VALUE  \
# 0      1      EFT     30    IP30     22.66
# 1      1      EFT     90    IP90     19.54
# 2      1      EFT    365   IP365      2.34
# 3      1      EFT   1825  IP1825      0.78
# 4      1      EFT   9125  IP9125      0.78
# ..   ...      ...    ...     ...       ...
# 245   88      EFT     30    IP30     99.22
# 246   88      EFT     90    IP90     88.28
# 247   88      EFT    365   IP365     24.22
# 248   88      EFT   1825  IP1825     13.28
# 249   88      EFT   9125  IP9125      5.46
#
#                                                   CUES STUDY
# 0    In about 1 month, I am going fishing with my f...    15
# 1    In about 3 months, I am eating dinner with my ...    15
# 2    In about 1 year, I am going deer hunting with ...    15
# 3    In about 5 years, I am attending my sister's r...    15
# 4    In about 25 years, I am having cake and ice cr...    15
# ..                                                 ...   ...
# ...

# %%
sheet3 = pd.read_excel('data/CLEAN_STUDY17.xlsx')
sheet3 = sheet3.rename(columns = {"ID":"SID"})
sheet3['STUDY'] = '17'
sheet3
# Out:
#      SID CATEGORY  DELAY     IP  IP VALUE  \
# 0      1      EFT     30   IP30     24.22
# 1      1      EFT     90   IP90     44.54
# 2      1      EFT    365  IP365     38.28
# 3      2      EFT     30   IP30     86.72
# 4      2      EFT     90   IP90      0.78
# ..   ...      ...    ...    ...       ...
# 202   68      EFT     90   IP90      5.46
# 203   68      EFT    365  IP365      0.78
# 204   69      EFT     30   IP30     97.66
# 205   69      EFT     90   IP90     96.10
# 206   69      EFT    365  IP365     74.22
#
#                                                   CUES STUDY
# 0    "In about 1 month I will at my daughters previ...    17
# 1    In about 6 months I am at Walt Disney World Ma...    17
# 2    In about 1 year I am going to be moving into a...    17
# 3    Incidentally, the other person living with me ...    17
# 4    I will be applying for Social Security online....    17
# ..                                                 ...   ...
# ...

# %%
sheet4 = pd.read_excel('data/CLEAN_STUDY19.xlsx')
sheet4 = sheet4.rename(columns = {"ID":"SID"})
sheet4['STUDY'] = '19'
sheet4
# Out:
#           SID CATEGORY  DELAY     IP  IP VALUE  \
# 0    2526-036      EFT     30   IP30     99.22
# 1    2526-036      EFT    180  IP180     49.22
# 2    2526-036      EFT    365  IP365     11.72
# 3    2526-004      EFT     30   IP30     89.84
# 4    2526-004      EFT    180  IP180     99.22
# ..        ...      ...    ...    ...       ...
# 166  2526-072      ERT    180  IP180     22.66
# 167  2526-072      ERT    365  IP365     49.22
# 168  2526-047      ERT     30   IP30     49.22
# 169  2526-047      ERT    180  IP180     11.72
# 170  2526-047      ERT    365  IP365      2.34
#
#                                                   CUES STUDY
# 0    In about 1 month I am at a movie with my frien...    19
# 1    In about 6 months I am visiting my uncle for t...    19
# 2    In about 1 year I am at my graduation ceremony...    19
# 3    In about 1 month I am skydiving at Western New...    19
# 4    In about 6 months I am visiting my friend in L...    19
# ...

# %%
sheet5 = pd.read_excel('data/CLEAN_STUDY6.xlsx')
sheet5 = sheet5.rename(columns = {"ID" : "SID"})
sheet5['STUDY'] = '6'
sheet5
# Out:
#      SID CATEGORY  DELAY     IP  IP VALUE  \
# 0    102      EFT     30   IP30     99.22
# 1    102      EFT    180  IP180     89.84
# 2    102      EFT    365  IP365     38.28
# 3    103      EFT     30   IP30     74.22
# 4    103      EFT    180  IP180     74.22
# ..   ...      ...    ...    ...       ...
# 238  354      EFT    180  IP180     99.22
# 239  354      EFT    365  IP365     99.22
# 240  355      EFT     30   IP30     97.66
# 241  355      EFT    180  IP180     89.84
# 242  355      EFT    365  IP365     50.78
#
#                                                   CUES STUDY
# 0    In about two months my son Brian and I are at ...     6
# 1    In about two months my son Brian and I are at ...     6
# 2    In about one year my son Brian and I are at Si...     6
# 3    Sophia and I will be arriving early at Canobie...     6
# 4    Sophia and I will be arriving early at Canobie...     6
# ..                                                 ...   ...
# ...

# %%
sheet6 = pd.read_excel('data/CLEAN_STUDY20.xlsx')
sheet6 = sheet6.rename(columns = {"ID" : "SID"})
sheet6['STUDY'] = '20'
sheet6
# Out:
#         SID CATEGORY  DELAY      IP  IP VALUE  \
# 0     75998      EFT    180   IP180     99.22
# 1     75998      EFT    730   IP730     99.22
# 2     75998      EFT   1825  IP1825     99.22
# 3     83294      EFT    180   IP180     99.22
# 4     83294      EFT    730   IP730     99.22
# ...     ...      ...    ...     ...       ...
# 997   16970      ERT    180   IP180      5.46
# 998   16970      ERT    180   IP180      5.46
# 999   13301      ERT    180   IP180     99.22
# 1000  13301      ERT    180   IP180     99.22
# 1001  13301      ERT    180   IP180     99.22
#
#                                                    CUES STUDY
# 0     In about 3 months, my husband and I are attend...    20
# 1     In about 1 year, I am at the grand opening of ...    20
# 2     In about 5 years, I will be on the beach in Ha...    20
# 3     In about 1 month I am at Chloe's Christmas par...    20
# 4     In about 1 year we will be having Thanksgiving...    20
# ...

# %%
sheet7 = pd.read_excel('data/CLEAN_STUDYSara.xlsx')
sheet7 = sheet7.rename(columns = {"ID" : "SID"})
sheet7['STUDY'] = 'Sara'
sheet7
# Out:
#      SID CATEGORY  DELAY     IP  IP VALUE  \
# 0      1      EFT     30   IP30     99.22
# 1      1      EFT    180  IP180     99.22
# 2      1      EFT    730  IP730      0.78
# 3      2      EFT     30   IP30     94.54
# 4      2      EFT    180  IP180     88.28
# ..   ...      ...    ...    ...       ...
# 475  159      EFT    180  IP180     58.60
# 476  159      EFT    730  IP730     35.16
# 477  160      EFT     30   IP30     46.10
# 478  160      EFT    180  IP180     24.22
# 479  160      EFT    730  IP730      5.46
#
#                                                   CUES STUDY
# 0    In about 1 month I am at the zoo. I am with my...  Sara
# 1    In about 6 months I am at the beach. I am with...  Sara
# 2    In about 2 years I am at the courthouse gettin...  Sara
# 3    In about 1 month I am on vacation in Italy. My...  Sara
# 4    In about 6 months I am at Disneyworld. My husb...  Sara
# ..                                                 ...   ...
# ...

# %%
sheet8 = pd.read_excel('data/CLEAN_STUDY16.xlsx')
sheet8 = sheet8.rename(columns = {"ID's" : "SID", "EFT/ERT":"CATEGORY","IP value":"IP VALUE", "cue_spellcheck":"CUES"})
sheet8['STUDY'] = '16'
sheet8.drop(['AUC EFT/ERT', 'BAUC', 'cue original'], axis = 1, inplace=True)
sheet8
# Out:
#             SID CATEGORY  DELAY     IP  IP VALUE  \
# 0      1 MS1001      EFT     30   IP30     49.22
# 1      1 MS1001      EFT    180  IP180     49.22
# 2      1 MS1001      EFT    365  IP365     11.72
# 3      2 MS1002      EFT     30   IP30     89.84
# 4      2 MS1002      EFT    180  IP180     89.84
# ..          ...      ...    ...    ...       ...
# 442  148 MS1148      ERT    180  IP180     10.16
# 443  148 MS1148      ERT    365  IP365      5.46
# 444  149 MS1149      ERT     30   IP30     94.54
# 445  149 MS1149      ERT    180  IP180     38.28
# 446  149 MS1149      ERT    365  IP365     24.22
#
#                                                   CUES STUDY
# 0    About 2 weeks from now I am visiting my husban...    16
# 1    In 6 months, I am visiting my mother in law. S...    16
# 2    In one year we are picking up my husband from ...    16
# 3    In 7 months I AM AT THE INN OF THE MOUNTAIN GO...    16
# 4    In 5 mins I will be at the July 4th fireworks ...    16
# ...

# %%
all_sheets = pd.concat([sheet1, sheet2, sheet8, sheet3, sheet4, sheet5, sheet6, sheet7])

# %%
all_sheets
# Out:
#            SID CATEGORY  DELAY     IP  IP VALUE  \
# 0    UB2MD201P      EFT     30   IP30    789.06
# 1    UB2MD201P      EFT    180  IP180    554.70
# 2    UB2MD201P      EFT    365  IP365    632.80
# 3     UB2MD207      EFT     30   IP30    351.56
# 4     UB2MD207      EFT    180  IP180    117.20
# ..         ...      ...    ...    ...       ...
# 475        159      EFT    180  IP180     58.60
# 476        159      EFT    730  IP730     35.16
# 477        160      EFT     30   IP30     46.10
# 478        160      EFT    180  IP180     24.22
# 479        160      EFT    730  IP730      5.46
#
#                                                   CUES STUDY
# 0    in about 1 month i am at the movies with my co...    14
# 1    in about 6 months my sister carolyn is home fr...    14
# 2    In about 1 year i am planning for christmas.  ...    14
# 3    In about one month I am kayaking on Lake Erie....    14
# 4    In about 6 months I am at the WHO concert in C...    14
# ...

# %%
all_sheets.to_excel('data/compiled_Data.xlsx', index = False)
