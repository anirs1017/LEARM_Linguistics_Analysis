# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# %%
data = pd.read_excel("EFTSTUDY16.xlsx", sheet_name='Sheet1')
data
# Out:
#            ID's EFT/ERT  AUC EFT/ERT      BAUC  DELAY     IP  IP value  \
# 0      1 MS1001     EFT     0.410466  0.007800     30   IP30     49.22
# 1      1 MS1001     EFT     0.410466  0.992200    180  IP180     49.22
# 2      1 MS1001     EFT     0.410466  0.943400    365  IP365     11.72
# 3      2 MS1002     EFT     0.896712  0.669900     30   IP30     89.84
# 4      2 MS1002     EFT     0.896712  0.992200    180  IP180     89.84
# ..          ...     ...          ...       ...    ...    ...       ...
# 442  148 MS1148     ERT     0.141452  0.141452    180  IP180     10.16
# 443  148 MS1148     ERT     0.141452  0.141452    365  IP365      5.46
# 444  149 MS1149     ERT     0.506411  0.506411     30   IP30     94.54
# 445  149 MS1149     ERT     0.506411  0.506411    180  IP180     38.28
# 446  149 MS1149     ERT     0.506411  0.506411    365  IP365     24.22
#
#                                           cue original  \
# 0    About 2 weeks from now I am visitingmy husband...
# 1    In 6 months, I am visiting my mother in law. S...
# 2    In one year we are picking up my husband from ...
# 3    In 7 months I AM AT THE INN OF THE MOUNTAIN GO...
# 4    I 5 mins the I will be at the July 4th fire wo...
# ..                                                 ...
# 442  About 144 hours ago I was watching my favorite...
# 443  About 288 hours ago I was watching a TV show, ...
# 444  24 HOURS AGO I WAS WITH JUSTIN.WE WERE AT WORK...
# 445  ABOUT 144 HOURS AGO I WAS AT BUFFALO WILD WING...
# 446  ABOUT 288 HOURS AGO I WAS AT LIBERTY PARK WITH...
#
#                                         cue_spellcheck
# 0    About 2 weeks from now I am visiting my husban...
# 1    In 6 months, I am visiting my mother in law. S...
# 2    In one year we are picking up my husband from ...
# 3    In 7 months I AM AT THE INN OF THE MOUNTAIN GO...
# 4    In 5 mins I will be at the July 4th fireworks ...
# ..                                                 ...
# 442  About 144 hours ago I was watching my favorite...
# 443  About 288 hours ago I was watching a TV show, ...
# 444  26 HOURS AGO I WAS WITH JUSTIN.WE WERE AT WORK...
# 445  ABOUT 144 HOURS AGO I WAS AT BUFFALO WILD WING...
# 446  ABOUT 288 HOURS AGO I WAS AT LIBERTY PARK WITH...
#
# [447 rows x 9 columns]

# %%
IP_values = pd.DataFrame(data['IP value'])
IP_time = pd.DataFrame(data['IP'])
delay = pd.DataFrame(data['DELAY'])
all_cues = pd.DataFrame(data['cue_spellcheck'])
category = pd.DataFrame(data['EFT/ERT'])

# %%
# len(delay['DELAY'])

# %%
def split_cues():
    eft = []
    ert = []
    
    for i in category.index:
        if category['EFT/ERT'][i] == "EFT":
            eft.append([all_cues['cue_spellcheck'][i], IP_values['IP value'][i]])
        else:
            ert.append([all_cues['cue_spellcheck'][i], IP_values['IP value'][i]])
    
    ind_eft_data = []
    ind_ert_data = []
#     IP_eft_values = []
#     IP_ert_values = []
    i = 0
    while(i != len(eft)):
        temp_eft = []
        temp_ert = []
        temp_eft_IP = 0
        temp_ert_IP = 0
        for j in range(3):
            temp_eft.append( eft[i+j][0] )
            temp_eft_IP += eft[i+j][1]
            temp_ert.append( ert[i+j][0] )
            temp_ert_IP += ert[i+j][1]
        
        ind_eft_data.append( [ temp_eft[0], temp_eft_IP/3 ] )
        ind_ert_data.append( [ temp_ert[0], temp_ert_IP/3 ] )
        i += 3
#             IP_eft_values.append(eft_data[i+j][1])
#             IP_ert_values.append(ert_data[i+j][1])
    
    return ind_eft_data, ind_ert_data

# %%
def collect_cues(toReturn):
    eft_data = {}
    ert_data = {}
    
    IP_EFT = {}
    IP_ERT = {}
    
    delay_periods = [30, 180, 365]
    for period in delay_periods:
        eft_data[period] = []
        ert_data[period] = []
        
        IP_EFT[period] = []
        IP_ERT[period] = []
        
    for i in category.index:
        current_delay = delay['DELAY'][i]
        current_cue = all_cues['cue_spellcheck'][i]
        current_IP = IP_values['IP value'][i]
        
        if category['EFT/ERT'][i] == "EFT":
            eft_data[current_delay].append([current_cue, current_IP])
            IP_EFT[current_delay].append(current_IP)
        else:
            ert_data[current_delay].append([current_cue, current_IP])
            IP_ERT[current_delay].append(current_IP)
    
    if (toReturn == 'IP'):
        return IP_EFT, IP_ERT
    else:
        return eft_data, ert_data

# %%
def clean_text(cue_data):
    corpus = []
    y = []
    for i in range(len(cue_data)):
        cue = re.sub('[^a-zA-Z]', ' ', cue_data[i][0])
        cue = cue.lower().split()
        ps = PorterStemmer()
        cue = [ps.stem(word) for word in cue if not word in set(stopwords.words('english'))]
        cue = ' '.join(cue)
        corpus.append(cue)
        
        y.append(cue_data[i][1])
    
    return corpus, np.array(y, dtype=np.int32).reshape(len(y), 1)

# %%
eft_data, ert_data = collect_cues('EFT')
IP_EFT, IP_ERT = collect_cues(toReturn = 'IP')
IP_EFT
# Out:
# {30: [49.22,
#   89.84,
#   0.78,
#   99.22,
#   94.54,
#   47.66,
#   25.78,
#   72.66,
#   99.22,
#   19.54,
#   38.28,
#   27.34,
#   64.84,
#   91.4,
#   74.22,
#   24.22,
#   99.22,
#   94.54,
#   97.66,
#   99.22,
#   8.6,
#   24.22,
#   74.22,
#   99.22,
#   42.96,
#   97.66,
#   49.22,
#   24.22,
#   71.1,
#   24.22,
#   92.96,
#   82.04,
#   99.22,
#   49.22,
#   49.22,
#   94.54,
#   89.84,
#   97.66,
#   74.22,
#   92.96,
#   96.1,
#   71.1,
#   89.84,
#   39.84,
#   99.22,
#   85.16,
#   89.84,
#   49.22,
#   99.22,
#   89.84,
#   85.16,
#   99.22,
#   57.04,
#   24.22,
#   86.72,
#   99.22,
#   99.22,
#   99.22,
#   97.66,
#   92.96,
#   96.1,
#   49.22,
#   89.84,
#   88.28,
#   89.84,
#   99.22,
#   99.22,
#   86.72,
#   99.22,
#   69.54,
#   41.4,
#   94.54,
#   50.78],
#  180: [49.22,
#   89.84,
#   0.78,
#   99.22,
#   86.72,
#   99.22,
#   11.72,
#   42.96,
#   99.22,
#   19.54,
#   86.72,
#   16.4,
#   80.46,
#   38.28,
#   66.4,
#   49.22,
#   99.22,
#   83.6,
#   49.22,
#   99.22,
#   8.6,
#   24.22,
#   89.84,
#   99.22,
#   24.22,
#   92.96,
#   24.22,
#   50.78,
#   69.54,
#   24.22,
#   5.46,
#   63.28,
#   99.22,
#   99.22,
#   24.22,
#   99.22,
#   69.54,
#   99.22,
#   69.54,
#   92.96,
#   24.22,
#   74.22,
#   80.46,
#   19.54,
#   99.22,
#   97.66,
#   64.84,
#   49.22,
#   69.54,
#   75.78,
#   85.16,
#   86.72,
#   49.22,
#   99.22,
#   86.72,
#   80.46,
#   99.22,
#   49.22,
#   99.22,
#   49.22,
#   99.22,
#   30.46,
#   80.46,
#   42.96,
#   89.84,
#   99.22,
#   94.54,
#   24.22,
#   74.22,
#   49.22,
#   89.84,
#   89.84,
#   39.84],
#  365: [11.72,
#   89.84,
#   0.78,
#   99.22,
#   94.54,
#   22.66,
#   7.04,
#   22.66,
#   99.22,
#   5.46,
#   30.46,
#   27.34,
#   10.16,
#   82.04,
#   41.4,
#   24.22,
#   99.22,
#   74.22,
#   49.22,
#   99.22,
#   3.9,
#   24.22,
#   49.22,
#   0.78,
#   24.22,
#   92.96,
#   10.16,
#   11.72,
#   24.22,
#   24.22,
#   11.72,
#   38.28,
#   24.22,
#   99.22,
#   33.6,
#   99.22,
#   60.16,
#   91.4,
#   49.22,
#   92.96,
#   19.54,
#   49.22,
#   75.78,
#   39.84,
#   99.22,
#   99.22,
#   49.22,
#   49.22,
#   69.54,
#   75.78,
#   49.22,
#   89.84,
#   49.22,
#   11.72,
#   80.46,
#   80.46,
#   99.22,
#   97.66,
#   94.54,
#   39.84,
#   99.22,
#   24.22,
#   72.66,
#   24.22,
#   89.84,
#   99.22,
#   89.84,
#   25.78,
#   74.22,
#   39.84,
#   33.6,
#   89.84,
#   10.16]}

# %% [markdown]
# ## Find Medians

# %%
def classifyCues(eft_medians, ert_medians):
    cue_labels = []
    
    for i in category.index:
        current_delay = delay['DELAY'][i]
        current_IP = IP_values['IP value'][i]
        
        if category['EFT/ERT'][i] == "EFT":
            if current_delay == 30:
                if current_IP < eft_medians.get(30):
                    cue_labels.append(0)
                else:
                    cue_labels.append(1)
            elif current_delay == 180:
                if current_IP < eft_medians.get(180):
                    cue_labels.append(0)
                else:
                    cue_labels.append(1)
            elif current_delay == 365:
                if current_IP < eft_medians.get(365):
                    cue_labels.append(0)
                else:
                    cue_labels.append(1)
            
        else:
            if current_delay == 30:
                if current_IP < ert_medians.get(30):
                    cue_labels.append(0)
                else:
                    cue_labels.append(1)
            elif current_delay == 180:
                if current_IP < ert_medians.get(180):
                    cue_labels.append(0)
                else:
                    cue_labels.append(1)
            elif current_delay == 365:
                if current_IP < ert_medians.get(365):
                    cue_labels.append(0)
                else:
                    cue_labels.append(1)
    
    return cue_labels

# %%
import statistics
eft_medians = {}
ert_medians = {}

for key, value in IP_EFT.items():
    value.sort()
    eft_medians[key] = statistics.median(value)

for key, value in IP_ERT.items():
    value.sort()
    ert_medians[key] = statistics.median(value)

# %%
print (eft_medians)
print (ert_medians)
# Out:
# {30: 88.28, 180: 74.22, 365: 49.22}
# {30: 80.46, 180: 45.32, 365: 37.5}

# %%
cue_labels = classifyCues(eft_medians, ert_medians)
len(cue_labels)
data['Cue - Good/Bad'] = cue_labels
data
# Out:
#            ID's EFT/ERT  AUC EFT/ERT      BAUC  DELAY     IP  IP value  \
# 0      1 MS1001     EFT     0.410466  0.007800     30   IP30     49.22
# 1      1 MS1001     EFT     0.410466  0.992200    180  IP180     49.22
# 2      1 MS1001     EFT     0.410466  0.943400    365  IP365     11.72
# 3      2 MS1002     EFT     0.896712  0.669900     30   IP30     89.84
# 4      2 MS1002     EFT     0.896712  0.992200    180  IP180     89.84
# ..          ...     ...          ...       ...    ...    ...       ...
# 442  148 MS1148     ERT     0.141452  0.141452    180  IP180     10.16
# 443  148 MS1148     ERT     0.141452  0.141452    365  IP365      5.46
# 444  149 MS1149     ERT     0.506411  0.506411     30   IP30     94.54
# 445  149 MS1149     ERT     0.506411  0.506411    180  IP180     38.28
# 446  149 MS1149     ERT     0.506411  0.506411    365  IP365     24.22
#
#                                           cue original  \
# 0    About 2 weeks from now I am visitingmy husband...
# 1    In 6 months, I am visiting my mother in law. S...
# 2    In one year we are picking up my husband from ...
# 3    In 7 months I AM AT THE INN OF THE MOUNTAIN GO...
# 4    I 5 mins the I will be at the July 4th fire wo...
# ..                                                 ...
# 442  About 144 hours ago I was watching my favorite...
# 443  About 288 hours ago I was watching a TV show, ...
# 444  24 HOURS AGO I WAS WITH JUSTIN.WE WERE AT WORK...
# 445  ABOUT 144 HOURS AGO I WAS AT BUFFALO WILD WING...
# 446  ABOUT 288 HOURS AGO I WAS AT LIBERTY PARK WITH...
#
#                                         cue_spellcheck  Cue - Good/Bad
# 0    About 2 weeks from now I am visiting my husban...               0
# 1    In 6 months, I am visiting my mother in law. S...               0
# 2    In one year we are picking up my husband from ...               0
# 3    In 7 months I AM AT THE INN OF THE MOUNTAIN GO...               1
# 4    In 5 mins I will be at the July 4th fireworks ...               1
# ..                                                 ...             ...
# 442  About 144 hours ago I was watching my favorite...               0
# 443  About 288 hours ago I was watching a TV show, ...               0
# 444  26 HOURS AGO I WAS WITH JUSTIN.WE WERE AT WORK...               1
# 445  ABOUT 144 HOURS AGO I WAS AT BUFFALO WILD WING...               0
# 446  ABOUT 288 HOURS AGO I WAS AT LIBERTY PARK WITH...               0
#
# [447 rows x 10 columns]

# %% [markdown]
# ## Entity recognition

# %%
def findEntities(cues):
    score = []
    POS_list = []
    verb_list = []
    valid_pos = ['NNP', 'NNS', 'PRP', 'NN', 'NNS', 'PDT']
    valid_verbs = ['VB', 'VBG', 'VBP', 'VBZ']
    for cue in cues:
        token = nltk.word_tokenize(cue)
        POS_components = nltk.pos_tag(token)
        count = 0
        temp = []
        temp2 = []
        for pos in POS_components:
            if pos[1] in valid_pos:
                count+=1
                temp.append(pos)
            
            ps = PorterStemmer()
            curr_verb = ps.stem(pos[0])
            if curr_verb not in set(stopwords.words('english')) and pos[1] in valid_verbs:
                temp2.append(curr_verb)
        if count >= 5:
            score.append([1, 'Good'])
        else:
            score.append([0, 'Bad'])
        POS_list.append(temp)
        verb_list.append(temp2)
    
    return score, POS_list, verb_list

# %%
def EntityRecognition():
    eft_cues = []
    ert_cues = []
    for i in category.index:
        current_cue = all_cues['cue_spellcheck'][i]
        if category['EFT/ERT'][i] == "EFT":
            eft_cues.append(current_cue)
        else:
            ert_cues.append(current_cue)
        
    
    eft_cue_score, pos_eft, verbs_eft = findEntities(eft_cues)
    ert_cue_score, pos_ert, verbs_ert = findEntities(ert_cues)
    
    return pd.DataFrame(eft_cue_score, columns = ['Score', 'Type']), pd.DataFrame(ert_cue_score, columns = ['Score', 'Type']), pos_eft, pos_ert, verbs_eft, verbs_ert

# %%
eft_scores, ert_scores, pos_eft, pos_ert, verbs_eft, verbs_ert = EntityRecognition()
eft_scores.index.name = 'Cue #'
ert_scores.index.name = 'Cue #'

# %%
eft_scores
# Out:
#        Score  Type
# Cue #
# 0          1  Good
# 1          1  Good
# 2          1  Good
# 3          1  Good
# 4          1  Good
# ...      ...   ...
# 214        1  Good
# 215        1  Good
# 216        1  Good
# 217        1  Good
# 218        1  Good
#
# [219 rows x 2 columns]

# %%
pos_eft[0]
# Out:
# [('weeks', 'NNS'),
#  ('I', 'PRP'),
#  ('husband', 'NN'),
#  ('state', 'NN'),
#  ('prison', 'NN'),
#  ('I', 'PRP'),
#  ('him', 'PRP'),
#  ('phone', 'NN'),
#  ('I', 'PRP'),
#  ('him', 'PRP'),
#  ('year', 'NN'),
#  ('I', 'PRP'),
#  ('tax', 'NN'),
#  ('check', 'NN'),
#  ('I', 'PRP'),
#  ('him', 'PRP'),
#  ('son', 'NN'),
#  ('I', 'PRP'),
#  ('him', 'PRP'),
#  ('we', 'PRP'),
#  ('ones', 'NNS'),
#  ('We', 'PRP'),
#  ('hours', 'NNS'),
#  ('him', 'PRP'),
#  ('hours', 'NNS')]

# %%
print(verbs_eft[0], '\n\n', verbs_eft[99])
# Out:
# ['visit', 'get', 'talk', 'see', 'wait', 'super', 'see', 'see', 'drive', 'visit']
#
#  ['ha', 'help', 'get']

# %%
ert_scores
# Out:
#        Score  Type
# Cue #
# 0          1  Good
# 1          1  Good
# 2          1  Good
# 3          1  Good
# 4          1  Good
# ...      ...   ...
# 223        1  Good
# 224        1  Good
# 225        1  Good
# 226        1  Good
# 227        1  Good
#
# [228 rows x 2 columns]

# %%
pos_ert[0]
# Out:
# [('hours', 'NNS'),
#  ('I', 'PRP'),
#  ('month', 'NN'),
#  ('ready', 'NN'),
#  ('bed', 'NN'),
#  ('I', 'PRP'),
#  ('him', 'PRP'),
#  ('bath', 'NN'),
#  ('him', 'PRP'),
#  ('stories', 'NNS'),
#  ('him', 'PRP'),
#  ('night', 'NN'),
#  ('I', 'PRP'),
#  ('he', 'PRP'),
#  ('me', 'PRP'),
#  ('night', 'NN'),
#  ('room', 'NN')]

# %%
print(verbs_ert[4], '\n\n', verbs_ert[199])
# Out:
# ['enjoy', 'watch', 'play', 'catch', 'enjoy', 'see', 'feel']
#
#  ['see']

# %%
eft_data[30][1][0]
# Out:
# 'In 7 months I AM AT THE INN OF THE MOUNTAIN GOS IN RUIDOSO NM WITH SHARON.WE WILL BE GAMBLING, DRINKING, LAUGHING, AND HAVING THE TIME OF OUR LIVES.'

# %%
corpus_30_eft, y_30_eft = clean_text(eft_data[30])
corpus_180_eft, y_180_eft = clean_text(eft_data[180])
corpus_365_eft, y_365_eft = clean_text(eft_data[365])

corpus_30_ert, y_30_ert = clean_text(ert_data[30])
corpus_180_ert, y_180_ert = clean_text(ert_data[180])
corpus_365_ert, y_365_ert = clean_text(ert_data[365])

# %% [markdown]
# #### Vectorize the corpus

# %%
from sklearn.feature_extraction.text import CountVectorizer

def vectorize(corpus):
    cv = CountVectorizer()
    cv.fit(corpus)
    vocab = cv.vocabulary_
#     print(vocab)
    X = cv.fit_transform(corpus).toarray()
    
    return vocab, X

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# cv = CountVectorizer()
# cv.fit(corpus_30_eft)
# vocab = cv.vocabulary_
# print(vocab)
# X_30_eft = cv.fit_transform(corpus_30_eft).toarray()

# %%
# X_30_eft

# %%
# len(X_30_eft[0])

# %% [markdown]
# ### Perform Principal Component Analysis

# %%
from sklearn.decomposition import PCA
n_comp = 10

def find_PCA(X, vocab):
    pca = PCA(n_components = n_comp)
    X = pca.fit_transform(X)
    explained_variance = pca.explained_variance_ratio_
    var = explained_variance
    
    # Create dataframe and calculate maximum values
    columns = []
    for i in range(n_comp):
        columns.append('PC-'+str(i+1))
    df = pd.DataFrame(pca.components_)
    new_df = pd.DataFrame.transpose(df) 
    new_df.columns = columns
#     new_df
    indices = new_df.idxmax(axis=0)
    
    important_words = influential_words(indices, vocab)
    
    return X, var, important_words

# %% [markdown]
# ### Create a dictionary of most influential words

# %%
def influential_words(indices, vocab):
    words = {}
    for index in indices:
        for key, value in vocab.items():
            if value == index:
                words[index] = key
    
    return words

# %%
def find_importance(corpus):
    vocab, X = vectorize(corpus)
    X, variance, important_words = find_PCA(X, vocab)
    
    results = []
    i = 0
    for key, value in important_words.items():
        results.append((value, round(variance[i], 3)))
        i+=1
#     results.append(variance)
#     results.append(important_words)
    
    return pd.DataFrame(results, columns = ['Word', 'Variance'])

# %%
eft_30_result = find_importance(corpus_30_eft)
eft_180_result = find_importance(corpus_180_eft)
eft_365_result = find_importance(corpus_365_eft)

ert_30_result = find_importance(corpus_30_ert)
ert_180_result = find_importance(corpus_180_ert)
ert_365_result = find_importance(corpus_365_ert)

# %%
eft_30_result
# Out:
#      Word  Variance
# 0    time     0.057
# 1   front     0.044
# 2  budget     0.037
# 3   enjoy     0.036
# 4     see     0.035
# 5    lego     0.030
# 6    work     0.029
# 7   place     0.028
# 8    feel     0.027
# 9    movi     0.026

# %%
eft_180_result
# Out:
#        Word  Variance
# 0       day     0.047
# 1     watch     0.041
# 2      year     0.037
# 3      look     0.036
# 4       see     0.033
# 5     enjoy     0.030
# 6  birthday     0.029
# 7    machin     0.026
# 8      time     0.025

# %%
eft_365_result
# Out:
#     Word  Variance
# 0    day     0.051
# 1   feel     0.048
# 2  excit     0.038
# 3    get     0.036
# 4  happi     0.035
# 5    new     0.031
# 6   ride     0.029
# 7  beach     0.028
# 8   time     0.026

# %%
ert_30_result
# Out:
#       Word  Variance
# 0    watch     0.062
# 1     read     0.057
# 2  lobster     0.053
# 3     work     0.047
# 4   realli     0.036
# 5   friend     0.033
# 6     play     0.032
# 7   center     0.031

# %%
ert_180_result
# Out:
#       Word  Variance
# 0  chicken     0.055
# 1  husband     0.050
# 2  groceri     0.046
# 3    enjoy     0.040
# 4   dollar     0.038
# 5     play     0.036
# 6     game     0.034
# 7    candi     0.031
# 8    watch     0.030
# 9    peopl     0.029

# %%
ert_365_result
# Out:
#      Word  Variance
# 0    play     0.061
# 1   drink     0.058
# 2    bowl     0.047
# 3  school     0.041
# 4   enjoy     0.037
# 5     abl     0.031
# 6   happi     0.029
# 7    time     0.028

# %%
# n_comp = 10
# from sklearn.decomposition import PCA
# pca = PCA(n_components = n_comp)
# X_30_eft = pca.fit_transform(X_30_eft)
# explained_variance = pca.explained_variance_ratio_
# explained_variance
# len(X_30_eft)

# %%
# columns = []
# for i in range(n_comp):
#     columns.append('PC-'+str(i+1))
# df = pd.DataFrame(pca.components_)
# new_df = pd.DataFrame.transpose(df) 
# new_df.columns = columns
# new_df

# %%
# print(new_df.max())
# print("\n\n\n")
# print(new_df.idxmax(axis = 0))
# indices = new_df.idxmax(axis=0)

# %%
# words = {}
# for index in indices:
#     for key, value in vocab.items():
#         if value == index:
#             words[index] = key

# words

# %% [markdown]
# # Part 2 - Analyzing the EFT and ERT Cues, individual wise

# %% [markdown]
# ### Get the cues first

# %%
eft_cues, ert_cues = split_cues()
len(ert_cues)
# Out:
# 73

# %% [markdown]
# ### Next, clean the data

# %%
X_eft, y_eft = clean_text(eft_cues)
X_ert, y_ert = clean_text(ert_cues)

# %%
# X_ert

# %% [markdown]
# ### Obtain the variances and words

# %%
eft_result = find_importance(X_eft)
ert_result = find_importance(X_ert)

# %% [markdown]
# ### Display the results

# %%
eft_result
# Out:
#      Word  Variance
# 0    time     0.057
# 1   front     0.044
# 2  budget     0.037
# 3   enjoy     0.036
# 4     see     0.035
# 5    lego     0.030
# 6     one     0.029
# 7   place     0.028
# 8    feel     0.027
# 9    movi     0.026

# %%
ert_result
# Out:
#       Word  Variance
# 0    watch     0.063
# 1     read     0.059
# 2  lobster     0.055
# 3     work     0.049
# 4   realli     0.037
# 5   friend     0.034
# 6      dog     0.033
# 7     play     0.032
# 8    enjoy     0.028

# %%
vocab_eft, X = vectorize(X_eft)
X, var_eft, important_eft = find_PCA(X, vocab_eft)
X = np.absolute(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_eft, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)
regressor.score(X_test, y_test)
# Out:
# -0.13804121506330413

# %%
import statsmodels.api as sm
def backwardElimination(x, y, sl):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    x = np.delete(x, j, 1)
    print(regressor_OLS.summary())
    return x

# %%
# import statsmodels.api as sm
X = np.append(arr = np.ones((len(X_30_eft), 1)).astype(int), values = X_30_eft, axis = 1)
X_opt = X[:, :]
regressor_OLS = sm.OLS(endog = y_30_eft, exog = X_opt).fit()
regressor_OLS.summary()
# SL = 0.05
# X_Modeled = backwardElimination(X_opt, y_30_eft, SL)
# X_Modeled
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.167
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     1.241
# Date:                Sat, 14 Sep 2019   Prob (F-statistic):              0.283
# Time:                        22:11:53   Log-Likelihood:                -340.46
# No. Observations:                  73   AIC:                             702.9
# Df Residuals:                      62   BIC:                             728.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         74.7292      5.974     12.509      0.000      62.787      86.671
# x1             6.0342      2.969      2.033      0.046       0.100      11.968
# x2            -2.7122      3.107     -0.873      0.386      -8.924       3.499
# x3            -3.9359      4.683     -0.840      0.404     -13.297       5.425
# x4           -11.2941      5.111     -2.210      0.031     -21.510      -1.078
# x5           -11.9438      6.755     -1.768      0.082     -25.448       1.560
# x6            14.4459      8.108      1.782      0.080      -1.762      30.654
# x7            -6.7197      5.605     -1.199      0.235     -17.924       4.485
# x8            17.1503      7.427      2.309      0.024       2.304      31.996
# x9            -2.2490      6.314     -0.356      0.723     -14.870      10.372
# x10           -2.2556      5.105     -0.442      0.660     -12.460       7.949
# ==============================================================================
# Omnibus:                        6.294   Durbin-Watson:                   1.711
# Prob(Omnibus):                  0.043   Jarque-Bera (JB):                6.256
# Skew:                          -0.673   Prob(JB):                       0.0438
# Kurtosis:                       2.503   Cond. No.                         8.87
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
